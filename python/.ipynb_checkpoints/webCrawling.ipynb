# %% [markdown]
# #### 자신이 원하는 쇼핑물 사이트에서 검색한 제품의 제품명 및 가격정보를 수집하세요.

# %%
import requests, bs4
import pandas as pd

targetUrl = "https://www.coupang.com/np/categories/449593"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
data = requests.get(targetUrl,headers=headers)
bs = bs4.BeautifulSoup(data.text, 'html.parser')

dataTag = bs.find("ul", {"id":"productList"})

nameTag = dataTag.find_all("div", {"class":"name"})

priceTag = dataTag.find_all("strong", {"class":"price-value"})

nameList = []
priceList = []

nameList = nameTag[0].text

priceList = priceTag[0].text

rowList = []

for i in range(0, len(nameTag)):
    nameList = nameTag[i].text
    priceList = priceTag[i].text
    totalList = [nameList, priceList] 
    rowList.append(totalList)
totalList = []

pd.DataFrame(rowList, columns=["상품", "가격(원)"])
# Out:
#                                                    상품   가격(원)
# 0                      \n    리세스 팝트 스낵 믹스, 226g, 1개\n   4,900
# 1           \n    팝코너스 크리스피 & 크런치 팝콘 칩 케틀, 198g, 3개\n  13,130
# 2                           \n    치토스 퍼프, 6개, 60.2g\n  13,810
# 3                          \n    치토스 크런치, 6개, 77.9g\n  14,200
# 4           \n    켈로그 라이스 크리스피 트리트 오리지널 바, 22g, 40개\n  17,800
# 5   \n    켈로그 팝 타르트 토스터 패이스트리 프로스트, 스모어 (S'mores),...   6,790
# 6                      \n    케틀브랜드 포테이토 칩, 142g, 1개\n   2,950
# 7     \n    켈로그 팝 타르트 토스터 패이스트리 프로스트 블루베리, 384g, 1개\n   2,640
# 8   \n    켈로그 팝 타르트 토스터 패이스트리, 384g, 쿠키 & 크림 (Cook...   6,690
# 9   \n    Kellogg's 라이스 크리스피 트리츠, 버스데이 케이크(Birthda...   7,350
# 10       \n    퀘이커 라이스 케이크 캐러멜 글루텐 프리 무지방, 186g, 1개\n   6,990
# 11          \n    프리토레이 먼치스 스낵 믹스 플레이밍 핫, 3개, 56.7g\n   5,070
# 12          \n    케틀브랜드 포테이토 칩 씨 솔트 & 비니거, 369g, 1개\n   5,190
# 13             \n    오르테가 타코 쉘 옐로우 콘 18개입, 246g, 1개\n   6,790
# 14            \n    Lays 스택스 포테이토 칩스 체다, 155.9g, 1개\n   2,490
# 15         \n    스테이시스 피타 칩 파마산 마늘 & 허브, 207.9g, 1개\n   3,860
# 16                \n    케틀브랜드 포테이토 칩 씨 솔트, 1개, 241g\n   3,890
# 17                  \n    치토스 크런치 플레이밍 핫, 3개, 77.9g\n   7,290
# 18          \n    콤보스 베이크드 스낵 크래커 체다 치즈, 178.6g, 2개\n   6,400
# 19              \n    Snack Pop 팝콘 트윅스 캔디, 1개, 149g\n   5,350
# 20  \n    팝코너스 더 크런치 앤 홀섬 팝드-콘 스낵 스파이시 퀘소 글루텐 프리, ...   4,610
# 21  \n    켈로그 유니콘 프루티 스낵 대즐 베리 글루텐 프리 무지방 10개입, 1개...   4,750
# 22         \n    Popcorners 체다 필 굿 팝트 콘 칩, 198g, 1개\n   3,900
# 23                      \n    허쉬 팝트 스낵 믹스, 226g, 4개\n  18,580
# 24                     \n    케틀브랜드 포테이토 칩, 241g, 1개\n   5,390
# 25        \n    퀘이커 글루텐 프리 라이스 케이크 애플 시나몬, 185g, 1개\n   5,290
# 26     \n    레이즈 스택스 포테이토 크리스프 솔트 앤 비니거, 155.9g, 3개\n   6,490
# 27          \n    켈로그 라이스 크리스피 트리트 더 오리지널, 22g, 8개입\n   5,390
# 28   \n    켈로그 팝 타르트 프로스트 스트로베리 밀크셰이크 8개입, 1개, 384g\n   6,790
# 29     \n    스테이시스 피타 칩 심플리 네이키드 파티 사이즈, 510.3g, 1개\n   9,820
# 30                \n    프링글스 포테이토 크리스프 피자, 158g, 1개\n   4,590
# 31                 \n    치토스 체다 할라피뇨 크런치, 6개, 56.7g\n  10,540
# 32           \n    데일리크레이브 베지 칩 글루텐 프리 비건, 170g, 1개\n   5,590
# 33           \n    Lakanto 몽크프루트 스위트너 클래식, 235g, 1개\n   7,130
# 34             \n    켈로그 팝 타르트 프로스트 시나몬 롤, 1개, 400g\n   6,000
# 35       \n    피크니크 오리지널 슈스트링 포테이토 글루텐 프리, 113g, 1개\n   4,290
# 36  \n    엑트 II 마이크로웨이브 팝콘 버터 러버 글루텐 프리 3개입, 234g,...   4,790
# 37        \n    인카크롭스 로스티드 자이언트 콘 오리지널, 113.4g, 2개입\n   8,340
# 38               \n    케틀브랜드 크링클 컷 포테이토 칩, 241g, 1개\n   5,390
# 39           \n    프링글스 포테이토 크리스프 솔트 & 식초, 158g, 1개\n   4,290
# 40              \n    가디토스 오리지널 레시피 스낵 믹스, 243g, 1개\n   5,290
# 41            \n    Lays 스택스 포테이토 칩스 오리지널, 163g, 1개\n   2,990
# 42             \n    사다프 골든 크리스피 프라이드 어니언, 284g, 1개\n   4,750
# 43       \n    첵스 세이보리 첵스 스낵 믹스 볼드 파티 블렌드, 248g, 1개\n   3,630
# 44  \n    켈로그 디즈니 프린세스 프루트 스낵 글루텐 프리 무지방 22개입, 1개,...   9,470
# 45              \n    첵스 세이보리 첵스 믹스 트레디셔널, 435g, 1개\n   6,370
# 46      \n    볼더캐년 포테이토 칩 몰트 비니거 & 씨 솔트, 184.6g, 1개\n   3,730
# 47   \n    챗햄빌리지 마늘 & 버터 트레디셔널 컷 베이크드 크루통, 142g, 2개\n   6,850
# 48         \n    팝코너스 크런치 앤 홀썸 팝콘 스낵 씨 솔트, 198g, 3개\n  10,450
# 49  \n    프링글스 메가 스택 사우어 크림 앤 어니언 포테이토 크리스프, 203g,...   4,290
# 50        \n    밥스레드밀 화이트 팝콘 글루텐 프리 홀 그레인, 850g, 1개\n   5,290
# 51  \n    케틀브랜드 오가닉 포테이토 칩, 142g, 1개, Salt & Fresh...   3,890
# 52               \n    케틀브랜드 포테이토 칩 240g 글루텐 프리, 1개\n   4,750
# 53               \n    케틀브랜드 포테이토 칩 240g 글루텐 프리, 1개\n   4,750
# 54  \n    켈로그 라이스 크리스피 트리츠 팝퍼 스냅 크래클, 쿠키 엔 크림 (Coo...   4,160
# 55     \n    테라칩스 리얼 베지터블 칩 스위트 포테이토 씨 솔트, 170g, 1개\n   5,340
# 56        \n    메이드인네이쳐 피기 팝 초코 크런치 수퍼 스낵, 119g, 1개\n   4,680
# 57             \n    Snack Pop 팝콘 스니커즈 캔디, 1개, 149g\n   5,350
# 58            \n    굿헬스 케틀 칩 아보카도 오일 씨 솔트, 142g, 1개\n   4,670
# 59                    \n    하피 포춘 쿠키 스낵, 113.4g, 1개\n   4,650

# %% [markdown]
# ### 2

# %%
# 라이브러리 선언
import requests, bs4
import pandas as pd
# Url 불러오기 headers 우회(맥 일반 사용자 인식)
targetUrl = "https://www.coupang.com/np/categories/449593"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:71.0) Gecko/20100101 Firefox/71.0'}
data = requests.get(targetUrl, headers=headers)
# parser를 통해 깔끔하게 보이게 함
bs = bs4.BeautifulSoup(data.text, 'html.parser')
# ul > div, strong 에서 name, price를 따로 변수지정
dataTag = bs.find("ul", {"id":"productList"})
nameTag = dataTag.find_all("div", {"class":"name"})
priceTag = dataTag.find_all("strong", {"class":"price-value"})
# List 초기화
rowList = []
nameList = []
priceList = []

for i in range(0, len(nameTag)):
    nameList = nameTag[i].text
    priceList = priceTag[i].text
    rowList.append([nameList, priceList])

product = pd.DataFrame(rowList, columns=["상품", "가격(원)"])
# 상품 1개 출력
product.head(1)
# Out:
#                                상품  가격(원)
# 0  \n    리세스 팝트 스낵 믹스, 226g, 1개\n  4,900

# %% [markdown]
# #### TIMEANDDATETIME내 SOUTHKOREA 연휴 정보 또는 자신이 원하는 테이블 정보를 수집하세요.

# %%
# 라이브러리 선언
import requests, bs4
import pandas as pd
# Url 불러오기
resp = requests.get("https://www.timeanddate.com/holidays/south-korea/")
resp.encoding='utf-8'
html = resp.text
# parser를 이용해 정리
bs = bs4.BeautifulSoup(html, 'html.parser')

tableTag = bs.find("table", {"id":"holidays-table"})
tbodyTag = tableTag.find(name = "tbody")
trs = tbodyTag.find_all(name = "tr")

# trs의 [0]은 빈 값
dateTag = trs[1].find_all(name = ["th", "td"])
# 디버깅용

# List 초기화
rowList = []
dateList = []
# for문 사용
for i in range(0, len(trs)):
    dateTag = trs[i].find_all(name = ["th", "td"])
    # trs[0],[7]~~의 값은 비어있기 때문에 if을 이용 continue로 스킵
    if dateTag == []:
        continue
    for j in range(0, len(dateTag)):
        # dateTag[2]의 값은 링크가 같이 나오기 때문에 text로 사용해야 함
        dateList.append(dateTag[j].text)
    rowList.append(dateList)
    dateList = []
# DataFrame을 만들고 columns를 따로 지정(Day:요일 부분은 값이 없음, 3중이 힘듦)
hoilday = pd.DataFrame(rowList, columns=["Date", "Day", "Name", "Type"])
hoilday.head()
# Out:
#      Date  Day             Name            Type
# 0   1월 1일  금요일   New Year's Day  Public Holiday
# 1  2월 11일  목요일  Seollal Holiday  Public Holiday
# 2  2월 12일  금요일          Seollal  Public Holiday
# 3  2월 13일  토요일  Seollal Holiday  Public Holiday
# 4  2월 14일  일요일  Valentine's Day      Observance

# %% [markdown]
# ### 2

# %%
# 라이브러리 선언
import requests, bs4
import pandas as pd
# Url 불러오기
resp = requests.get("https://www.timeanddate.com/holidays/south-korea/")
resp.encoding='utf-8'
html = resp.text
# parser를 이용해 정리
bs = bs4.BeautifulSoup(html, 'html.parser')
# table > tbody > tr > th, td
tableTag = bs.find("table", {"id":"holidays-table"})

tbodyTag = tableTag.find("tbody")

trTag = tbodyTag.find_all("tr")

dateTag = trTag[1].find_all(["th", "td"])

dateTag

# List 초기화
rowList = []
dateList = []

# for문 사용
for i in range(0, len(trTag)):
    dateTag = trTag[i].find_all(name = ["th", "td"])
    # trs[0],[7]~~의 값은 비어있기 때문에 if을 이용 continue로 스킵
    if dateTag == []:
        continue
    for j in range(0, len(dateTag)):
        # dateTag[2]의 값은 링크가 같이 나오기 때문에 text로 사용해야 함
        dateList.append(dateTag[j].text)
    rowList.append(dateList)
    dateList = []
    
# DataFrame을 만들고 columns를 따로 지정(page에 컬럼 Day:요일 부분은 값이 없음)
hoilday = pd.DataFrame(rowList, columns=["Date", "Day", "Name", "Type"])
hoilday
